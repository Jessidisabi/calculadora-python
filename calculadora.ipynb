# %% [markdown]
# <a href="https://colab.research.google.com/github/Jessidisabi/calculadora-python/blob/main/calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importando s bibliotecas
# lembra matematica basica
# sem usar o numpy
import numpy as np
# matemática básica

# %%
numero1 = float(input('informe o primeiro número'))
numero2 = float(input('informe o segundo número'))

# soma
soma = numero1 + numero2
print(soma)
# subtração
subtracao = numero1 - numero2
print(subtracao)
# divisão
divi = numero1/numero2
print(divi)
#multiplicação
multi = numero1 * numero2
print(multi)
# Out:
# informe o primeiro número10
# informe o segundo número5
# 15.0
# 5.0
# 2.0
# 50.0

# %%
# usando o numpy
# matemática básica
numero1 = float(input('informe o primeiro número'))
numero2 = float(input('informe o segundo número'))

# soma pode ser sum ou add
print(f'soma: {np.add(numero1,numero2)}')
# ou o método sum - só para numeros interios
# print(f'soma: {np.sum(numero1, numero2)}')

# subtrair
print(f'subtração: {np.subtract(numero1, numero2)}')
# multiplicar
print(f'multiplicação: {np.multiply(numero1,numero2)}')
#dividir
print(f'divisão: {np.divide(numero1,numero2)}')
# Out:
# informe o primeiro número10
# informe o segundo número5
# soma: 15.0
# subtração: 5.0
# multiplicação: 50.0
# divisão: 2.0

# %%
while True:
  # while True nao necessita de uma condição para
  # inicio ou fim
  # ------
  # para finalizar o while true usamos o caso BREAK
  print('---- CALCULADORA ----')
  print('1 - somar')
  print('2 - subtrair')
  print('3 - multiplicar')
  print('4 - dividir')
  print('0 - sair')

  op = input('escolha a opção')
# lembre da indentação no caso, quem responde a quem
  if op == "0":
    break
  elif op == "1":
    print(soma)
  elif op == "2":
    print(subtracao)
  elif op == "3":
    print(multi)
  elif op == "4":
    print(divi)
  else:
    print('Op nao encontrada')

# %%
#usando sistema de calculadora - caixa de supermercado
# quais elementos tem o pagamento?

# temos produtos
# temos quantidades
# temos um total
lista_nome = []
lista_quantidade = []
lista_valor = []
while True:

  op_tem = input('Tem algum produto para passar? S/N')
  if op_tem.lower() == 'n':
    print('sistema finalizado')
    break
  elif op_tem.lower() == 's':
    while True:
      # precisamos de variaveis
      # precisamos de listas

      nome = input('Qual o produto?')
      valor = float(input('Qual o valor'))
      quantidade = float(input('Qual a qunatidade'))
      lista_nome.append(nome)
      lista_valor.append(valor)
      lista_quantidade.append(quantidade)

      op_novo_produto = input('tem outro produto? S/N')

      if op_novo_produto.lower() == 'n':
        print('indo para a nota fical')
        # vai ter coisas aqui
        print('---- CUMPOM FISCAL ----')
        print('Produto | Valor | Quantidade | Total')
        # i - produto --- j - valor ----- k - quantidade ---- l - total
        # o total é uma multiplicação - valor e a quantidade
        # transformar a lista em numpy
        np_valor = np.array(lista_valor)
        np_quantidade = np.array(lista_quantidade)
        # np.array() - transforma um conjunto de numeros para numpy
        total = np.multiply(np_valor, np_quantidade)
        for i,j,k,l in zip(lista_nome, lista_valor, lista_quantidade, total):
          print(i,j,k,l)
        break
      else:
        print('informe o novo produto')
# Out:
# Tem algum produto para passar? S/Ns
# Qual o produto?milho
# Qual o valor2.00
# Qual a qunatidade3
# tem outro produto? S/Nn
# indo para a nota fical
# ---- CUMPOM FISCAL ----
# Produto | Valor | Quantidade | Total
# milho 2.0 3.0 6.0
# Tem algum produto para passar? S/Nn
# sistema finalizado
